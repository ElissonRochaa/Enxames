# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import drive 
drive.mount('/content/gdrive')

# base = pd.read_csv('gdrive/My Drive/Deep Learning/fall_detection/competition/CompleteDataSet_training_competition.csv',
#                    index_col="TimeStamps",parse_dates=[0])
abc = pd.read_csv('gdrive/My Drive/Colab Notebooks/Enxames/abc_.csv')
fss = pd.read_csv('gdrive/My Drive/Colab Notebooks/Enxames/fss_.csv')
pso = pd.read_csv('gdrive/My Drive/Colab Notebooks/Enxames/pso_.csv')

abc2 = pd.read_csv('gdrive/My Drive/Colab Notebooks/Enxames/abc_2.csv')
fss2 = pd.read_csv('gdrive/My Drive/Colab Notebooks/Enxames/fss_2.csv')
pso2 = pd.read_csv('gdrive/My Drive/Colab Notebooks/Enxames/pso_2.csv')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
iteracoes = len(abc.values[:,0])
print(iteracoes)

i = 0

while i < 3: 
  #plt.title('Função '+ str(k)+ ' com W tipo ' + str(l))
  #plt.plot(range(0,iteracoes), pso.values[:,i], 'r--', label='PSO')
  plt.plot(pso.values[:,i], 'r--', label='PSO')
  #i += 1
  #plt.plot(range(0,iteracoes), fss.values[:,i], 'bs', label='FSS')
  plt.plot(fss.values[:,i], 'bs', label='FSS')
  #i += 1
  #plt.plot(range(0,iteracoes), abc.values[:,i], 'g^', label='ABC')
  plt.plot(abc.values[:,i], 'g^', label='ABC')
  
  plt.ylabel('fitness')
  #plt.ylim(-100, 1000)
  plt.xlabel('iteracoes')
  #plt.axis([0, iteracoes, -100, iteracoes])
  legend = plt.legend(loc='upper center', shadow=True, fontsize='x-large')
  # Put a nicer background color on the legend.
  legend.get_frame().set_facecolor('C0')


  plt.show()
  
  plt.plot(pso.values[:,i], 'r--', label='PSO')
  #i += 1
  #plt.plot(range(0,iteracoes), fss.values[:,i], 'bs', label='FSS')
  plt.plot(fss.values[:,i], 'bs', label='FSS')
  #i += 1
  #plt.plot(range(0,iteracoes), abc.values[:,i], 'g^', label='ABC')
  plt.plot(abc.values[:,i], 'g^', label='ABC')
  i += 1
  plt.ylabel('fitness')
  plt.ylim(-100, 1000)
  plt.xlabel('iteracoes')
  #plt.axis([0, iteracoes, -100, iteracoes])
  legend = plt.legend(loc='upper center', shadow=True, fontsize='x-large')
  # Put a nicer background color on the legend.
  legend.get_frame().set_facecolor('C0')


  plt.show()
# Out:
# 2227

# %%
for i in range(0, 3):
  data = [pso2.values[:,i], fss2.values[:,i], abc2.values[:,i]]
  fig, ax = plt.subplots()
  ax.boxplot(data)
  plt.show()
